# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\deves\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
news_api_key = "d3ca8002eec9431496f2f462095a461e"

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key = news_api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="Bitcoin",
    language="en"
)
bitcoin_news["totalResults"]
# Out:
# 8086

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="Ethereum",
    language="en"
)
ethereum_news["totalResults"]
# Out:
# 3885

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments =[]
for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        positive = sentiment["pos"]
        neutral = sentiment["neu"]
        negative = ["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": positive,
            "negative": negative,
            "neutral": neutral
            
        })
        
    except AttributeError:
        pass
 
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-07-12  Miners voluntarily powered down as energy dema...    0.1531
# 1  2022-07-25  You gotta hand it to some people for being imp...    0.5994
# 2  2022-07-16  People in Russia will soon no longer be allowe...    0.0516
# 3  2022-07-21  Elon Musk-owned electric vehicle making compan...    0.2023
# 4  2022-06-30  Grayscale Investments has announced its intent...   -0.2732
#
#    positive negative  neutral
# 0     0.057    [neg]    0.902
# 1     0.130    [neg]    0.835
# 2     0.088    [neg]    0.855
# 3     0.053    [neg]    0.947
# 4     0.059    [neg]    0.853

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-07-23  Less than two weeks into its soft launch, Game...   -0.1531
# 1  2022-07-06  Axie Infinity was the prime example of crypto ...    0.2263
# 2  2022-07-25  The Ethereum Merge is significant, and not jus...    0.2023
# 3  2022-07-11  Ethereum and Bitcoin have nearly become househ...    0.2500
# 4  2022-07-15  Whether you own cryptocurrency or not, the Eth...    0.0000
#
#    positive  negative  neutral
# 0     0.000     0.045    0.955
# 1     0.077     0.000    0.923
# 2     0.048     0.000    0.952
# 3     0.065     0.000    0.935
# 4     0.000     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive     neutral
# count  100.000000  100.000000  100.000000
# mean     0.031058    0.060790    0.886800
# std      0.438387    0.061751    0.079238
# min     -0.862500    0.000000    0.641000
# 25%     -0.296000    0.000000    0.837250
# 50%      0.000000    0.058000    0.890500
# 75%      0.361200    0.100500    0.938000
# max      0.888500    0.271000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.176973    0.082870    0.042650    0.874450
# std      0.434337    0.072748    0.066191    0.088883
# min     -0.936600    0.000000    0.000000    0.633000
# 25%     -0.029800    0.000000    0.000000    0.826500
# 50%      0.258750    0.074500    0.000000    0.893500
# 75%      0.510600    0.122500    0.069750    0.933250
# max      0.921600    0.299000    0.354000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = {'down', 'crypto', 'bear', 'including', 'today', 'announced', 'week', 'month', 'lower', 'char','also', 
             'reutersdado'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)

   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    # Remove the stop words
    filtered_words = [word for word in sw if word not in stopwords.words('english')]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['text'].apply(word_tokenize)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-07-12  Miners voluntarily powered down as energy dema...    0.1531
# 1  2022-07-25  You gotta hand it to some people for being imp...    0.5994
# 2  2022-07-16  People in Russia will soon no longer be allowe...    0.0516
# 3  2022-07-21  Elon Musk-owned electric vehicle making compan...    0.2023
# 4  2022-06-30  Grayscale Investments has announced its intent...   -0.2732
#
#    positive negative  neutral  \
# 0     0.057    [neg]    0.902
# 1     0.130    [neg]    0.835
# 2     0.088    [neg]    0.855
# 3     0.053    [neg]    0.947
# 4     0.059    [neg]    0.853
#
#                                               tokens
# 0  [Miners, voluntarily, powered, down, as, energ...
# 1  [You, got, ta, hand, it, to, some, people, for...
# 2  [People, in, Russia, will, soon, no, longer, b...
# 3  [Elon, Musk-owned, electric, vehicle, making, ...
# 4  [Grayscale, Investments, has, announced, its, ...

# %%
# Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df['text'].apply(word_tokenize)
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-07-23  Less than two weeks into its soft launch, Game...   -0.1531
# 1  2022-07-06  Axie Infinity was the prime example of crypto ...    0.2263
# 2  2022-07-25  The Ethereum Merge is significant, and not jus...    0.2023
# 3  2022-07-11  Ethereum and Bitcoin have nearly become househ...    0.2500
# 4  2022-07-15  Whether you own cryptocurrency or not, the Eth...    0.0000
#
#    positive  negative  neutral  \
# 0     0.000     0.045    0.955
# 1     0.077     0.000    0.923
# 2     0.048     0.000    0.952
# 3     0.065     0.000    0.935
# 4     0.000     0.000    1.000
#
#                                               tokens
# 0  [Less, than, two, weeks, into, its, soft, laun...
# 1  [Axie, Infinity, was, the, prime, example, of,...
# 2  [The, Ethereum, Merge, is, significant, ,, and...
# 3  [Ethereum, and, Bitcoin, have, nearly, become,...
# 4  [Whether, you, own, cryptocurrency, or, not, ,...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

bit_tokenizer = tokenizer(text)
print(bit_tokenizer)
# Out:
# ['happenedtodays', 'crypto', 'selloff', 'ha', 'stymied', 'much', 'positive', 'sentiment', 'weve', 'seen', 'materialize', 'sector', 'recent', 'week', 'pm', 'et', 'top', 'cryptocurrenciesbitcoinbtc', 'char']

# %%
# Generate the Bitcoin N-grams where N=2
def word_counter(corpus): 
    string = ' '.join(corpus.text)
    processed = tokenizer(string)
    bigrams = ngrams(processed, n=2)# Generate the Bitcoin N-grams where N=2
    top_10 = dict(Counter(bigrams).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['bigram', 'count'])
    
word_counter(bitcoin_df)
# Out:
#                bigram  count
# 0     (july, reuters)     17
# 1        (char, july)      8
# 2    (digital, asset)      6
# 3  (bitcoin, holding)      6
# 4     (june, reuters)      5
# 5      (char, crypto)      5
# 6       (hard, drive)      4
# 7  (reuters, bitcoin)      4
# 8        (year, char)      4
# 9      (el, salvador)      4

# %%
# Generate the Ethereum N-grams where N=2
word_counter(ethereum_df)
# Out:
#                      bigram  count
# 0        (nft, marketplace)      8
# 1       (char, ethereumeth)      8
# 2              (char, july)      5
# 3           (july, reuters)      5
# 4  (cryptocurrency, market)      5
# 5          (crypto, market)      5
# 6              (last, year)      4
# 7          (digital, asset)      4
# 8               (char, new)      4
# 9    (consensus, mechanism)      4

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top10_btc = ' '.join(bitcoin_df.text)
processed_btc = tokenizer(top10_btc) 
token_count(processed_btc)
# Out:
# [('char', 99),
#  ('bitcoin', 48),
#  ('ha', 31),
#  ('cryptocurrency', 27),
#  ('crypto', 27),
#  ('reuters', 24),
#  ('july', 17),
#  ('digital', 16),
#  ('said', 13),
#  ('year', 12)]

# %%
# Use token_count to get the top 10 words for Ethereum
top10_eth = ' '.join(ethereum_df.text)
processed_eth = tokenizer(top10_eth) 
token_count(processed_eth)
# Out:
# [('char', 97),
#  ('crypto', 31),
#  ('ha', 27),
#  ('cryptocurrency', 21),
#  ('market', 18),
#  ('ethereum', 17),
#  ('nft', 16),
#  ('year', 15),
#  ('investor', 15),
#  ('bitcoin', 14)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wordcloud = WordCloud(colormap="Spectral_r").generate(bitcoin_df.text.str.cat())
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 50, "fontweight": "bold"}
plt.title("BTC Word Cloud", fontdict=fontdict)
plt.show()

# %%
# Generate the Ethereum word cloud
wordcloud = WordCloud(colormap="Dark2_r").generate(ethereum_df.text.str.cat())
plt.imshow(wordcloud)
plt.axis("off")
fontdict = {"fontsize": 50, "fontweight": "bold"}
plt.title("Eth Word Cloud", fontdict=fontdict)
plt.show()

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
#!python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bit_cat_text = bitcoin_df.text.str.cat()

# %%
# Run the NER processor on all of the text
btc_doc = nlp(bit_cat_text)
#btc_doc

# Add a title to the document
btc_doc.user_data['title'] = "Bitcoin NER"

# %%
# Render the visualization
options = {"compact": True, "color": "blue", "word_spacing": 25}
displacy.render(btc_doc, style='ent', options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# </br>An aerial view of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Whinstone US Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  mining facility in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rockdale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 9th, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The long sheds at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Ameri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# … [+3770 chars]You gotta hand it to some people for being impetuous even in the face of extraordinary odds. Imagine looking for a single hard drive amidst a literal heap of trash. Well, thats been one
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  goal … [+4091 chars]People in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will soon no longer be allowed to use digital assets as a form of payment.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vladimir Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has signed a bill into law prohibiting the use of digital assets, such as … [+1436 chars]Elon
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -owned electric vehicle making company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has sold a significant amount of its
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  holdings, the firm said in a statement. Reporting its earnings for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the company said that it had … [+2850 chars]Grayscale
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Investments
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has announced its intention to sue
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  after the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  regulator rejected its proposal to list a spot bitcoin
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Just an hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  after the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  re… [+1567 chars]July 27 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6.85%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22,717.05
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0

# %%
# List all Entities
for ent in btc_doc.ents:
    print(ent.text, ent.label_)
# Out:
# the Whinstone US Bitcoin ORG
# Rockdale GPE
# Texas GPE
# October 9th, 2021 DATE
# North Ameri GPE
# UK GPE
# mans NORP
# Russia GPE
# Russian NORP
# Vladimir Putin PERSON
# Musk PERSON
# Tesla ORG
# Bitcoin NORP
# Q2 CARDINAL
# Investments ORG
# the Securities and Exchange Commission ORG
# US GPE
# ETF ORG
# Just an hour TIME
# SEC ORG
# Reuters ORG
# 6.85% PERCENT
# 22,717.05 MONEY
# 22:05 CARDINAL
# GMT WORK_OF_ART
# Wednesday DATE
# 1,457.27 MONEY
# 29.1% PERCENT
# 2021 DATE
# Tesla ORG
# $936 million MONEY
# the second quarter of 2022 DATE
# Bitcoin NORP
# 75 CARDINAL
# chars]July 30 DATE
# Reuters ORG
# 3.36% PERCENT
# 24,584.24 MONEY
# GMT WORK_OF_ART
# Saturday DATE
# 798.93 MONEY
# 39.7% PERCENT
# the year DATE
# 2022 DATE
# Wednesday DATE
# $2.3 billion MONEY
# second-quarter DATE
# a record $3.3 billion MONEY
# first ORDINAL
# chars]July 12 DATE
# Reuters ORG
# winter DATE
# two CARDINAL
# +3895 GPE
# chars]July 19 DATE
# Reuters ORG
# months DATE
# chars]NEW YORK GPE
# July 20 DATE
# Reuters ORG
# Wednesday DATE
# Tesla Inc ORG
# TSLA.O ORG
# about 75% PERCENT
# fiat ORG
# El Salvador GPE
# Nayib Bukele PERSON
# Bitcoin ORG
# more than 50 percent PERCENT
# this year DATE
# 30 CARDINAL
# Reuters ORG
# 6.1% PERCENT
# 18,866.77 MONEY
# GMT WORK_OF_ART
# Thursday DATE
# 1,226.41 MONEY
# 60.9% PERCENT
# year DATE
# ten CARDINAL
# Wednesday DATE
# approximately 75% PERCENT
# Democrats NORP
# the Environmental Protection Agency ORG
# Department of Energy ORG
# US GPE
# chars]July 29 DATE
# Reuters ORG
# Bitcoin Valley WORK_OF_ART
# Honduran NORP
# Santa Lucia GPE
# June 30 DATE
# Reuters ORG
# Jacobi Asset Management ORG
# Thursday DATE
# Europe LOC
# first ORDINAL
# ETF ORG
# 2009 DATE
# the last few years DATE
# Bitcoin ORG
# the last month DATE
# Ethereum 2.0 ORG
# second ORDINAL
# Salvador ORG
# Tuesday DATE
# $1.6 billion MONEY
# Central America LOC
# la PERSON
# first ORDINAL
# CNN Business' Before ORG
# Bell ORG
# +6882 chars]WASHINGTON GPE
# June 30 DATE
# Reuters ORG
# U.S. GPE
# Thursday DATE
# South African NORP
# chars]NEW YORK GPE
# July 19 DATE
# Reuters ORG
# Texas GPE
# July 21 DATE
# Reuters ORG
# Brazilian NORP
# Mercado Bitcoin PERSON
# Mexican NORP
# the end of the year DATE
# Latin Amer GPE
# the Central African Republic LOC
# Kristy Kilburn PERSON
# LONDON GPE
# June 30 DATE
# Reuters ORG
# The European Union ORG
# Thursday DATE
# Salvador ORG
# 6.5 million CARDINAL
# Mexico GPE
# Bitso PRODUCT
# bitco ORG
# +4849 chars]NEW YORK PERSON
# July 12 DATE
# Reuters ORG
# The U.S. Securities and Exchange Commission ORG
# Tuesday DATE
# Cathie Wood's ORG
# Arc Inves ORG
# the years DATE
# Scientific ORG
# June DATE
# winter DATE
# 7,202 CARDINAL
# Dutch NORP
# Ukraine GPE
# Musk PERSON
# Twitter PRODUCT
# Wednesday DATE
# Tesladumped ORG
# 75% PERCENT
# last quarter DATE
# Monday DATE
# $1 trillion MONEY
# first ORDINAL
# June 13 DATE
# Matt Turner PERSON
# Insider Weekly ORG
# today DATE
# Ben Tobin PERSON
# Fairlead Strategies' ORG
# Katie Stockton PERSON
# over 80% PERCENT
# last year DATE
# accordi PERSON
# 2008 DATE
# Musk PERSON
# Twitter PRODUCT
# Wednesday DATE
# Tesladumped ORG
# 75% PERCENT
# last quarter DATE
# El Salvador GPE
# $222 million MONEY
# 75% PERCENT
# the Securities and Exchange Commission ORG
# Block GPE
# 2022 DATE
# six months DATE
# Xiaomi ORG
# one-inch QUANTITY
# 50.3 CARDINAL
# Sony ORG
# Sony ORG
# Xperia Pro PERSON
# chars]The European Union ORG
# James Howells PERSON
# UK GPE
# Newport GPE
# Wales GPE
# Coinbase Global PERSON
# monthly DATE
# 2011 last month DATE
# Texas GPE
# this October DATE
# GamesBeat Summit Next ORG
# today DATE
# the Ethereum Merge LAW
# 2014 DATE
# Merge PERSON
# second ORDINAL
# chars]July 28 DATE
# Reuters ORG
# more than 56% PERCENT
# this year DATE
# PAULO PERSON
# July 25 DATE
# Reuters ORG
# Brazilian NORP
# XP Inc ORG
# XP.O DATE
# mid-August DATE
# 2014 DATE
# Merge PERSON
# second ORDINAL
# Scaramucci PRODUCT
# SkyBridge Capital ORG
# one CARDINAL
# Bloomberg GPE
# Legion Strategies ORG
# Howells GPE
# 6 CARDINAL
# Newport GPE
# Wales GPE
# two CARDINAL
# Justin Sullivan PERSON
# Getty Images ORG
# Nilay Patel PERSON
# earlier this year DATE
# a month ago DATE
# yesterday DATE
# $1.2 billion MONEY
# Blockchain.com ORG
# Kraken ORG
# Coinbase PERSON
# hundreds CARDINAL
# this year DATE
# chars]LONDON ORG
# July 3 DATE
# Reuters ORG
# the Central African Republic LOC
# Faustin-Archange Touadera WORK_OF_ART
# Sunday DATE
# +1538 ORG
# Howells GPE
# 8,000 CARDINAL
# Mike Novogratz PERSON
# more than 50% PERCENT
# this year DATE
# +2431 chars]Critique ORG
# thousands CARDINAL
# chars]LONDON ORG
# July 13 DATE
# Reuters ORG
# Wednesday DATE
# Meta ORG
# Novi ORG
# chars]MUMBAI GPE
# July 6 DATE
# Reuters ORG
# India GPE
# up to 90% PERCENT
# US GPE
# Voyager Digital PERSON
# August DATE
# Pokemon ORG
# Sky Mavis PERSON
# $15 million MONEY
# June 30 DATE
# Reuters ORG
# Singapore GPE
# Three CARDINAL
# Three CARDINAL
# +2003 chars]In 2013 ORG
# Cleve Mesidor PERSON
# Department of Commerce ORG
# Mesidor PERSON
# FTX ORG
# Sam Bankman-Fried PERSON
# Reuters ORG
# Wednesday DATE
# Thursday DATE
# Tesla ORG
# second-quarter DATE
# as high as 10% PERCENT
# Thursday DATE
# Tesla ORG
# Nasdaq ORG
# Europe LOC
# Wednesday DATE
# Tesla ORG
# second-quarter DATE
# +1517 chars]In PERSON
# 18th-century DATE
# Castle Craig PERSON
# Peebles GPE
# Roy ORG
# 29-year-old DATE
# 49.99 MONEY
# Euros PERSON
# Voyager Digital Ltd. ORG
# Intelligent Sustainability ORG
# 24/7 CARDINAL
# Cleveland Working Paper ORG
# 22-19 DATE
# PagesPosted ORG
# 22 CARDINAL
# Jun 2022 ORG
# June 21, 2022
#  DATE
# Abstract ORG
# The Lightning Network ORG
# Bitcoin NORP
# US GPE
# Robert Kiyosaki PERSON
# this week DATE
# +1866 chars]US ORG
# Thursday DATE
# three CARDINAL
# more than 1% PERCENT
# second ORDINAL
# the Federal Reserve ORG
# 26 CARDINAL
# Reuters ORG
# the bleak winter DATE
# Reuters ORG
# the bleak winter DATE
# Thursday DATE
# millions of dollars MONEY
# chars]LONDON ORG
# July 5 DATE
# Reuters ORG
# Hilbert Capital PERSON
# Cevian Capital ORG
# Richard Murray PERSON
# Tuesday DATE
# Murray PERSON
# November 2021 DATE
# two-thirds CARDINAL
# $3 trillion MONEY
# Ignatova PERSON
# Cryptoqueen WORK_OF_ART
# FBI ORG
# Wanted Fugitive ORG
# billions of dollars MONEY
# Celsius Network PERSON
# 1bn MONEY
# this year DATE
# the coming months DATE
# 2022 first half DATE
# 500 CARDINAL
# 25-26% PERCENT
# chars]The Federal Bureau of Investigation ORG
# Ruja Ignatova PERSON
# Cryptoqueen WORK_OF_ART
# ten CARDINAL
# FBI ORG
# Thursday DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_cat_text = ethereum_df.text.str.cat()

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_cat_text)
eth_doc

# Add a title to the document
eth_doc.user_data['title'] = "Etheteum NER"

# %%
# Render the visualization
options = {"compact": True, "color": "blue", "word_spacing": 25}
displacy.render(eth_doc, style='ent', options=options)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Etheteum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than two weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into its soft launch,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GameStops
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFT marketplace is already courting controversy. Among the NFTs listed on the platform is an artwork called
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Falling Man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Web3 … [+1429 chars]Axie Infinity was the prime example of crypto gaming
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when its play-to-earn formula helped it reach
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to 2.7 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  active users
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last November
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . But that all came crashing down in Ma… [+1604
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]The Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is significant, and not just for people who own crypto. In the works in one form or another since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the long-delayed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will see the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>Bitcoin was created as an alternative, decentralized currency. … [+9267 chars]Whether you own cryptocurrency or not,
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  is a big deal. In the works since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the long-delayed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will see ethereum, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -biggest blockchain behind bitcoin, become nearly… [+9848 chars]Ethereum will improve upon its scalability after the completion of the so-called surge, co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>At
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ethereum Community Conference
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , he addressed overall… [+1344 chars]It's a way off the $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  all-time-high, but the ether cryptocurrency is showing signs of life after a long downward spiral that began in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Following news that the long-awaited
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  co… [+1616 chars]Over
# <mark class="entity" style="background: #bfe1d9; padding:

# %%
# List all Entities
for ent in eth_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Less than two weeks DATE
# GameStops ORG
# Falling Man PERSON
# last year DATE
# up to 2.7 million MONEY
# daily DATE
# last November DATE
# chars]The Ethereum Merge PERSON
# 2014 DATE
# Merge PERSON
# second ORDINAL
# the Ethereum Merge LAW
# 2014 DATE
# Merge PERSON
# second ORDINAL
# Vitalik Buterin PERSON
# Thursday DATE
# the Ethereum Community Conference ORG
# Paris GPE
# 4,800 MONEY
# April DATE
# Ethereum Merge ORG
# the last month DATE
# Ethereum 2.0 ORG
# second ORDINAL
# chars]DeFi GPE
# the "wild west PRODUCT
# the first six months of 2022 DATE
# the first half of this DATE
# chars]July 30 DATE
# Reuters ORG
# 3.36% PERCENT
# 24,584.24 MONEY
# GMT WORK_OF_ART
# Saturday DATE
# 798.93 MONEY
# 39.7% PERCENT
# the year DATE
# chars]July 27 DATE
# Reuters ORG
# 6.85% PERCENT
# 22,717.05 MONEY
# 22:05 CARDINAL
# GMT WORK_OF_ART
# Wednesday DATE
# 1,457.27 MONEY
# 29.1% PERCENT
# 80% PERCENT
# the past few hours TIME
# NIRV ORG
# U.S. GPE
# 8 cents MONEY
# CoinGecko ORG
# Blockchain.com ORG
# Kraken ORG
# Coinbase PERSON
# hundreds CARDINAL
# chars]GameStop ORG
# NFT ORG
# Monday DATE
# Ethereum ORG
# Scaramucci PRODUCT
# SkyBridge Capital ORG
# one CARDINAL
# Bloomberg GPE
# Legion Strategies ORG
# 14 CARDINAL
# Reuters ORG
# NFT ORG
# OpenSea ORG
# Thursday DATE
# about 20% PERCENT
# 30 CARDINAL
# Reuters ORG
# 6.1% PERCENT
# 18,866.77 MONEY
# GMT WORK_OF_ART
# Thursday DATE
# 1,226.41 MONEY
# 60.9% PERCENT
# year DATE
# Alejandro Jodorowskys Dune PERSON
# Wednesday DATE
# one CARDINAL
# NFT ORG
# 100 CARDINAL
# 150,00 MONEY
# Intels Arc Alchemist ORG
# Toms Hardware GPE
# Intel ORG
# Arc A380 ORG
# chars]GameStop ORG
# NFT ORG
# Falling Man WORK_OF_ART
# +8005 chars]It's ORG
# winter DATE
# second ORDINAL
# around 40% PERCENT
# the past seven days DATE
# 1,6 MONEY
# Today DATE
# chars]The Fine Print: WORK_OF_ART
# recent years DATE
# July 19 DATE
# Phil Rosen PERSON
# NYC LOC
# 1969 DATE
# Neil Armstrong PERSON
# Buzz Aldrin PERSON
# five decades DATE
# a year ago DATE
# Phil Rosen PERSON
# Los Angeles GPE
# today DATE
# Monday DATE
# $1 trillion MONEY
# first ORDINAL
# June 13 DATE
# NFT ORG
# 57 CARDINAL
# 150,000 MONEY
# Franklin Caldwell PERSON
# YouTube PRODUCT
# the British Army ORG
# Sunday DATE
# Elon Musk PRODUCT
# Army ORG
# 14 CARDINAL
# GameStop's PRODUCT
# NFT ORG
# NFT ORG
# NFT ORG
# millions CARDINAL
# only an estimated $44,5 MONEY
# Ethereum ORG
# Ethereum ORG
# Layer 2 PERSON
# one CARDINAL
# 12-month DATE
# June DATE
# PoS ORG
# PoS ORG
# Thursday DATE
# Jerome Powell PERSON
# the Federal Reserve ORG
# US GPE
# Meta ORG
# 2021 DATE
# 50% PERCENT
# 42,733 MONEY
# 2022 DATE
# 24,109 MONEY
# Voyager PRODUCT
# chars]The Securities and Exchange Commission ORG
# Thursday DATE
# Coinbase PRODUCT
# Sameer Ramani PERSON
# Dan Frommer
#  PERSON
# many years DATE
# Ethereums ORG
# GameStop ORG
# NFT ORG
# earlier this month DATE
# one CARDINAL
# NFT ORG
# Falling Man PERSON
# September 11, 2001 DATE
# the years DATE
# chars]Ethereum(ETH -6.68% PERCENT
# Ethereum ORG
# second ORDINAL
# 4,892 MONEY
# November 2021 DATE
# $100 million MONEY
# last week DATE
# North Korean NORP
# American Express ORG
# chars]NEW YORK GPE
# June 30 DATE
# Reuters ORG
# Doug Milnes PERSON
# January of this year DATE
# chars]July 5 DATE
# Reuters ORG
# NFT ORG
# last year DATE
# billions of dollars MONEY
# chars]July 5 DATE
# Reuters ORG
# NFT ORG
# last year DATE
# billions of dollars MONEY
# ETH 5.58% PERCENT
# Ethereu GPE
# StackCommerce ORG
# 1.9% PERCENT
# early afternoon TIME
# +2542 ORG
# Saturday DATE
# the day DATE
# about 11:45 a.m. TIME
# ET PERSON
# 6.17% PERCENT
# about 10% PERCENT
# chars]Ethereum(ETH 3.48% PERCENT
# the past two years DATE
# recent months DATE
# chars]Ethereum(ETH 1.54% PERCENT
# Shiba GPE
# -0.45% PERCENT
# Ethereum ORG
# second ORDINAL
# Tuesday DATE
# Amazon ORG
# Tesla ORG
# -2.97% PERCENT
# Thursday DATE
# morning TIME
# weeks DATE
# Celsius Network PERSON
# +2524 chars]Ethereum(ETH -4.68% ORG
# more than 60% PERCENT
# this year DATE
# +3448 chars]Ethereum(ETH ORG
# -4.14% PERCENT
# second ORDINAL
# dApps ORG
# Ethereum ORG
# 9.92% PERCENT
# Sunday DATE
# last week DATE
# 4:00 TIME
# this week DATE
# the day DATE
# Today DATE
# Second-quarter 2022 DATE
# 0.9% PERCENT
# a year ago DATE
# U.S. GPE
# tod PERSON
# Ethereum(ETH -4.45% ORG
# more than 49% PERCENT
# the last three weeks DATE
# Sept. 19 DATE
# chars]In 2013 PERSON
# Cleve Mesidor PERSON
# Department of Commerce ORG
# Mesidor PERSON
# +4683 chars]In PERSON
# the last few weeks DATE
# Bitcoin ORG
# Coinbase Global PERSON
# 78.5% PERCENT
# November last year DATE
# over 26,000 CARDINAL
# over 12,000 CARDINAL
# 2019 DATE
# Thursday DATE
# the Reddit Avatar Builder ORG
# chars]GameStop ORG
# first ORDINAL
# May DATE
# Ethereum ORG
# -0.88% PERCENT
# a week DATE
# CoinMarketCap ORG
# Ethereum Classic ORG
# 72% PERCENT
# the past seven days DATE
# today DATE
# 10.7% PERCENT
# Celsius Networks PERSON
# Chapter 11 LAW
# CNBC ORG
# late Wednesday TIME
# New Jersey GPE
# chars]GameStop ORG
# NFT ORG
# Monday DATE
# $3.5 million MONEY
# 50 CARDINAL
# NFT ORG
# ETH ORG
# second ORDINAL
# one CARDINAL
# US GPE
# Houston GPE
# the next three years DATE
# Sybil ORG
# Ethereum(ETH -7.58% PERCENT
# these days DATE
# Ethereum ORG
# Dan Frommer
#  PERSON
# Ethereum(ETH -4.85% ORG
# 30% PERCENT
# just the past week DATE
# "The Merge WORK_OF_ART
# Sept. 19 DATE
# Ethereum ORG
# ETH 4.08% PERCENT
# metho PERSON
# today DATE
# this morning TIME
# 24 hours TIME
# 4.17% PERCENT
# 4,892 MONEY
# November 2021 DATE
# Ethereum ORG
# 77% PERCENT
# $1 trillion MONEY
# 0.20% PERCENT
# this morning TIME
# recent days DATE
# 6.21% PERCENT
# the weekend DATE
# a turbulent week DATE
# the Federal Reserve ORG
# July DATE
# Today DATE
# recent weeks DATE
# 12:30 p.m. ET TIME
# -4.00% PERCENT

# %% [markdown]
# ---
